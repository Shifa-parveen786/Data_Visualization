# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/Multiplication_Table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A learning app generates multiplication tables
#-------------------------------------------------------
# Function to print multiplication table of a number
def multiplication_table(n):
    # Loop from 1 to 10
    for i in range(1, 11):
        result = n * i          # Calculate product
        print(result, end=" ")  # Print in same line


# Taking input from user
num = int(input("Enter number: "))

# Calling the function
multiplication_table(num)
# Out:
# Enter number: 3
# 3 6 9 12 15 18 21 24 27 30
