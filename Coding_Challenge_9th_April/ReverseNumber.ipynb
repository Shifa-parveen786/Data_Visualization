# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/ReverseNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A security system reverses numeric codes
#--------------------------------------------------
# Function to reverse a number
def reverse_number(num):
    # Initialize reversed number as 0
    rev = 0

    # Loop until number becomes 0
    while num > 0:
        digit = num % 10        # Get last digit
        rev = rev * 10 + digit  # Build reversed number
        num //= 10              # Remove last digit

    # Return reversed number
    return rev


# Taking input from user
num = int(input("Enter number: "))

# Calling the function and storing result
result = reverse_number(num)

# Printing the result
print(result)
# Out:
# Enter number: 1234
# 4321
