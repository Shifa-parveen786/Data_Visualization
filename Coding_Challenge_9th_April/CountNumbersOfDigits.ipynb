# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/CountNumbersOfDigits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A system analyzes numeric inputs
#-----------------------------------------------------------------------
# Function to calculate sum of digits of a number
def sum_of_digits(num):
    # Initialize sum as 0
    total = 0

    # Loop until number becomes 0
    while num > 0:
        digit = num % 10   # Get last digit
        total += digit     # Add digit to total
        num //= 10         # Remove last digit

    # Return sum of digits
    return total


# Taking input from user
num = int(input("Enter number: "))

# Calling the function and storing result
result = sum_of_digits(num)

# Printing the result
print(result)
# Out:
# Enter number: 123
# 6
