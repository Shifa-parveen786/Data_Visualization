# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/FindLongestWord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A parser extracts longest word
#------------------------------------------------------
# Function to find the longest word in a sentence
def find_longest_word(sentence):
    # Split the sentence into words
    words = sentence.split()

    # Assume first word is the longest
    longest = words[0]

    # Loop through each word
    for word in words:
        # Check if current word is longer
        if len(word) > len(longest):
            longest = word   # Update longest word

    # Return the longest word
    return longest


# Taking input from user
sentence = input("Enter a sentence: ")

# Calling the function and storing result
result = find_longest_word(sentence)

# Printing the result
print(result)
# Out:
# Enter a sentence: i love programming
# programming
