# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/LeapYear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A calender application checks leap years.
#--------------------------------------------------
# Function to check if a year is a leap year
def is_leap_year(year):
    # A year is leap if:
    # It is divisible by 4 AND not divisible by 100
    # OR it is divisible by 400
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
        return "Leap Year"
    else:
        return "Not Leap Year"


# Taking input from user
year = int(input("Enter year: "))

# Calling the function and storing result
result = is_leap_year(year)

# Printing the result
print(result)
# Out:
# Enter year: 2004
# Leap Year
