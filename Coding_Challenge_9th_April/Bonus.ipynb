# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/Bonus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A company gives bonus based on employee salary
#----------------------------------------------------
# taking user input
salary = int(input("Enter salary: "))

bonus = salary * 0.07   # 7% bonus
print("Bonus =", int(bonus))
# Out:
# Enter salary: 25000
# Bonus = 1750
