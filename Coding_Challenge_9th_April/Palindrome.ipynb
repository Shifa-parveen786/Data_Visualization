# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A system validates palindrome numbers
#-----------------------------------------------------
# Function to check if a number is palindrome
def is_palindrome(num):
    # Store original number
    original = num

    # Initialize reversed number
    rev = 0

    # Reverse the number
    while num > 0:
        digit = num % 10
        rev = rev * 10 + digit
        num //= 10

    # Check if original and reversed are same
    if original == rev:
        return "Palindrome"
    else:
        return "Not Palindrome"


# Taking input from user
num = int(input("Enter number: "))

# Calling the function and storing result
result = is_palindrome(num)

# Printing the result
print(result)
# Out:
# Enter number: 121
# Palindrome
