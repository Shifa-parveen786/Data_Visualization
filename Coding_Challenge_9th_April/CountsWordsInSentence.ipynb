# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/CountsWordsInSentence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A tool counts words
#--------------------------------------------------
# Function to count number of words in a sentence
def count_words(sentence):
    # Split sentence into words using space
    words = sentence.split()

    # Return the number of words
    return len(words)


# Taking input from user
sentence = input("Enter a sentence: ")

# Calling the function and storing result
result = count_words(sentence)

# Printing the result
print(result)
# Out:
# Enter a sentence: python is great
# 3
