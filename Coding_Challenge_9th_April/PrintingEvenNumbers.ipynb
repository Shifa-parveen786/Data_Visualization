# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/PrintingEvenNumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A system filters even numbers
#----------------------------------------------------
# Function to print even numbers from 1 to N
def print_even_numbers(n):
    # Loop from 1 to n
    for i in range(1, n + 1):
        # Check if number is even
        if i % 2 == 0:
            print(i, end=" ")   # Print even numbers in same line


# Taking input from user
n = int(input("Enter value of N: "))

# Calling the function
print_even_numbers(n)
# Out:
# Enter value of N: 10
# 2 4 6 8 10
