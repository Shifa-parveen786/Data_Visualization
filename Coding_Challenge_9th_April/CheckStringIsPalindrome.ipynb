# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/CheckStringIsPalindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A validation tool checks palindrome strings
#------------------------------------------------------
# Function to check if a string is palindrome
def is_palindrome_string(text):
    # Reverse the string using slicing
    reversed_text = text[::-1]

    # Compare original and reversed string
    if text == reversed_text:
        return "Yes"
    else:
        return "No"


# Taking input from user
text = input("Enter a string: ")

# Calling the function and storing result
result = is_palindrome_string(text)

# Printing the result
print(result)
# Out:
# Enter a string: madam
# Yes
