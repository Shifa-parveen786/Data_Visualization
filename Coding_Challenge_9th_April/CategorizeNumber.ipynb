# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/CategorizeNumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A finance tool categorizes numbers
#-------------------------------------------
# Function to check whether a number is positive, negative, or zero
def check_number(num):
    # Check if number is greater than 0
    if num > 0:
        return "Positive"

    # Check if number is less than 0
    elif num < 0:
        return "Negative"

    # If number is equal to 0
    else:
        return "Zero"


# Taking input from user
num = int(input("Enter a number: "))

# Calling the function and storing result
result = check_number(num)

# Printing the result
print(result)
# Out:
# Enter a number: -5
# Negative
