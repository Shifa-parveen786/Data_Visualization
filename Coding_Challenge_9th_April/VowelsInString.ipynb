# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/VowelsInString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A text Analyzer counts vowels
#--------------------------------------------------------
# Function to count vowels in a string
def count_vowels(text):
    # Initialize counter
    count = 0

    # Loop through each character in the string
    for ch in text:
        # Check if character is a vowel
        if ch in "aeiouAEIOU":
            count += 1   # Increase count

    # Return total vowel count
    return count


# Taking input from user
text = input("Enter a string: ")

# Calling the function and storing result
result = count_vowels(text)

# Printing the result
print(result)
# Out:
# Enter a string: shifa
# 2
