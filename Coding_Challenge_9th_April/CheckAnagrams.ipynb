# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/Coding_Challenge_9th_April/CheckAnagrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A system checks Anagrams
#-----------------------------------------------------
# Function to check if two strings are anagrams
def check_anagram(str1, str2):
    # Convert both strings to lowercase (optional, for case-insensitive check)
    str1 = str1.lower()
    str2 = str2.lower()

    # Check if sorted characters are equal
    if sorted(str1) == sorted(str2):
        return True
    else:
        return False


# Taking input from user
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

# Calling the function and storing result
result = check_anagram(str1, str2)

# Printing the result
print(result)
# Out:
# Enter first string: listen
# Enter second string: silent
# True
