# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/TotalBill3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculating the price after discount
#----------------------------------------------------------------------------
# taking user input

price = float(input("Enter price: "))
# using while loop
#---------------------------------------------------------------------------
while True:
    discount = float(input("Enter discount percentage: "))
    if 0 <= discount <= 100:
        break
    else:
        print("Invalid discount! Enter a value between 0 and 100.")

final_price = price * (1 - discount / 100)
print("Final price after discount: ₹", final_price)
# Out:
# Enter price: 300
# Enter discount percentage: 25
# Final price after discount: ₹ 225.0
