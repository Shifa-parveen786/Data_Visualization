# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/SI3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculating simple interest using lambda function
#----------------------------------------------------
simple_interest = lambda p, r, t: (p * r * t) / 100

p = float(input("Enter principal: "))
r = float(input("Enter rate of interest (%): "))
t = float(input("Enter time (years): "))

print("Simple Interest:", simple_interest(p, r, t))
# Out:
# Enter principal: 30
# Enter rate of interest (%): 10
# Enter time (years): 5
# Simple Interest: 15.0
