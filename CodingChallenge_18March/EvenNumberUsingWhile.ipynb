# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/EvenNumberUsingWhile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Print all even numbers between 1 to N
#----------------------------------------
n = int(input("Enter a number: "))
# using while loop
#----------------------------------------
i = 2
while i <= n:
    print(i)
    i += 2
# Out:
# Enter a number: 12
# 2
# 4
# 6
# 8
# 10
# 12
