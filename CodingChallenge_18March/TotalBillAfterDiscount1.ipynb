# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/TotalBillAfterDiscount1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculate total bill after discount
#--------------------------------------------------------------
# function with input validation
def calculate_discounted_price(price, discount):
    if price < 0:
        return "Price cannot be negative!"
    if discount < 0 or discount > 100:
        return "Discount must be between 0% and 100%!"
    final_price = price * (1 - discount / 100)
    return round(final_price, 2)
#---------------------------------------------------------------
# Input with validation
while True:
    try:
        price = float(input("Enter price: "))
        discount = float(input("Enter discount percentage: "))
        break
    except ValueError:
        print("Invalid input! Please enter numbers only.")
#-------------------------------------------------------------------
# Calculate
final_price = calculate_discounted_price(price, discount)
print(f"Final price after discount: ₹{final_price}")
# Out:
# Enter price: 500
# Enter discount percentage: 20
# Final price after discount: ₹400.0
