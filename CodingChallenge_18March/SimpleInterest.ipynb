# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/SimpleInterest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to calculate simple ineterest
#----------------------------------------------------
def calculate_simple_interest(p, r, t):
    si = (p * r * t) / 100
    return si

# Taking input
#-----------------------------------------------------
principal = float(input("Enter principal amount: "))
rate = float(input("Enter rate of interest: "))
time = float(input("Enter time (in years): "))

# Function call
#---------------------------------------------------------
interest = calculate_simple_interest(principal, rate, time)
#-----------------------------------------------------------
print("Simple Interest:", interest)
# Out:
# Enter principal amount: 80
# Enter rate of interest: 20
# Enter time (in years): 25
# Simple Interest: 400.0
