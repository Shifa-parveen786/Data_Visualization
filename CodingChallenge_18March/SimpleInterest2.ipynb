# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/SimpleInterest2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculating Simple Interest
#----------------------------------------------------------------
# function with return value
def simple_interest(principal, rate, time):
    """
    Calculate simple interest.
    SI = (Principal * Rate * Time) / 100
    """
    return (principal * rate * time) / 100
#-------------------------------------------------------------------
# Input
p = float(input("Enter principal amount: "))
r = float(input("Enter rate of interest (%): "))
t = float(input("Enter time in years: "))
#-----------------------------------------------------------------------
# Calculate SI
si = simple_interest(p, r, t)
print("Simple Interest:", si)
# Out:
# Enter principal amount: 150
# Enter rate of interest (%): 13
# Enter time in years: 2
# Simple Interest: 39.0
