# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/BillAfterDiscount.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#calculate total bill after discount
#----------------------------------------------------------
price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))
#---------------------------------------------------------
final_price = price * (1 - discount / 100)
#Price after discount---------------------------------------
print("Final price after discount:", final_price)
# Out:
# Enter price: 100
# Enter discount percentage: 20
# Final price after discount: 80.0
