# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/printEvenNum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print even numbers 1 to N
# using list comprehension
n = int(input("Enter a number: "))

even_numbers = [i for i in range(1, n + 1) if i % 2 == 0]
print(even_numbers)
