# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/ElectBill4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# calculate electricity bill based on units consumed
#-----------------------------------------------------
def calculate_electricity_bill(units):
    bill = 0
    if units <= 100:
        bill = units * 5
    elif units <= 200:
        bill = 100 * 5 + (units - 100) * 7
    else:
        bill = 100 * 5 + 100 * 7 + (units - 200) * 10
    return bill
#--------------------------------------------------------
# Input
units = int(input("Enter units consumed: "))
#--------------------------------------------------------
# Calculate bill
bill = calculate_electricity_bill(units)
print("Electricity bill: ₹", bill)
# Out:
# Enter units consumed: 100
# Electricity bill: ₹ 500
