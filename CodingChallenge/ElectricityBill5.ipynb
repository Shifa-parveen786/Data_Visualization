# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/ElectricityBill5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Electricity bill based on units consumed
#-------------------------------------------------------
# Function-based calculation
#----------------------------------------------------------
def calculate_bill(units):
    if units <= 100:
        return units * 5
    elif units <= 200:
        return 100 * 5 + (units - 100) * 7
    else:
        return 100 * 5 + 100 * 7 + (units - 200) * 10
#-----------------------------------------------------------
# Input
units = int(input("Enter units consumed: "))
#-----------------------------------------------------------
# Calculate bill
bill = calculate_bill(units)
print("Electricity bill: ₹", bill)
# Out:
# Enter units consumed: 250
# Electricity bill: ₹ 1700
