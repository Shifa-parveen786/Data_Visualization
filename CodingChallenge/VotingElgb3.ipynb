# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/VotingElgb3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# a person is eligible for vote or not
#----------------------------------------------------------
#using boolean function
#-----------------------------------------------------------
def is_eligible_to_vote(age):
    return age >= 18

# TAking Input
age = int(input("Enter your age: "))

# Checking eligibility
if is_eligible_to_vote(age):
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age: 20
# You are eligible to vote.
