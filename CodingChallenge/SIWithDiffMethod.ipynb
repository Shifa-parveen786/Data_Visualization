# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/SIWithDiffMethod.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to calculate simple ineterest
#------------------------------------------------
def simple_interest(principal, rate=5, time=1):
    return (principal * rate * time) / 100

# Taking User input
#-------------------------------------------------
p = float(input("Enter principal: "))
r = float(input("Enter rate of interest (%): "))
t = float(input("Enter time (years): "))
# calling function
#--------------------------------------------------
si = simple_interest(p, r, t)
print("Simple Interest:", si)
# Out:
# Enter principal: 70
# Enter rate of interest (%): 15
# Enter time (years): 10
# Simple Interest: 105.0
