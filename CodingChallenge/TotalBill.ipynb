# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/TotalBill.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Calculate total bill after discount
#--------------------------------------------------------
#taking input from the user
price = float(input("Enter price: "))
discount = float(input("Enter discount percentage: "))
#---------------------------------------------------------
final_price = price - (price * discount / 100)
print(f"Final price after discount: {final_price:.2f}")
# Out:
# Enter price: 200
# Enter discount percentage: 25
# Final price after discount: 150.00
