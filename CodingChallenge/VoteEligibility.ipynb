# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/DAVIS_Python_Programming/blob/main/CodingChallenge/VoteEligibility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Whether a person is eligible to vote or not
#-----------------------------------------------
age = int(input("Enter the age of the person:"))
#-----------------------------------------------
if(age<18):
  print("The person is not eligible to vote")
else:
  print("The person is eligible to vote ")
# Out:
# Enter the age of the person:19
# The person is eligible to vote
