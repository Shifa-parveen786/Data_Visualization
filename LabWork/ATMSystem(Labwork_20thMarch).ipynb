# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/ATMSystem(Labwork_20thMarch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ATM Withdrawl System
def atm():
    balance = 10000  # Initial balance

    while True:
        print("\nCurrent Balance:", balance)
        amount = float(input("Enter withdrawal amount (0 to exit): "))

        # Exit condition
        if amount == 0:
            print("Thank you for using ATM!")
            break

        # Validation
        elif amount < 0:
            print("Invalid amount! Enter positive value.")

        elif amount > balance:
            print("Insufficient balance!")

        else:
            balance -= amount
            print("Withdrawal successful!")
            print("Remaining Balance:", balance)

# Run ATM system
atm()
# Out:
# Current Balance: 10000
# Enter withdrawal amount (0 to exit): 500
# Withdrawal successful!
# Remaining Balance: 9500.0
#
# Current Balance: 9500.0
# Enter withdrawal amount (0 to exit): 5000
# Withdrawal successful!
# Remaining Balance: 4500.0
#
# Current Balance: 4500.0
