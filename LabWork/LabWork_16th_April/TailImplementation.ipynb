# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/LabWork_16th_April/TailImplementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("file1.txt", "r")
lines = f.readlines()

n = int(input("Enter number of lines: "))

for line in lines[-n:]:
    print(line.strip())

f.close()
