# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/LabWork_16th_April/OneFileToAnother.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program to copy contents of one file into another

# open source file in read mode
source = open("source.txt", "r")

# open destination file in write mode
destination = open("destination.txt", "w")

# read data from source file
data = source.read()

# write data into destination file
destination.write(data)

# close both files
source.close()
destination.close()

print("File copied successfully!")
