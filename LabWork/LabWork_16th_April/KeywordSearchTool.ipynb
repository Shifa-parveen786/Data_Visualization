# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/LabWork_16th_April/KeywordSearchTool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("file1.txt", "r")

keyword = input("Enter keyword: ")

for line in f:
    if keyword in line:
        print(line.strip())

f.close()
