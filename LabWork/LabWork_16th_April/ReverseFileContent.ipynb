# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/LabWork_16th_April/ReverseFileContent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("file1.txt", "r")
lines = f.readlines()

out = open("reverse.txt", "w")

for line in lines[::-1]:
    out.write(line)

f.close()
out.close()
