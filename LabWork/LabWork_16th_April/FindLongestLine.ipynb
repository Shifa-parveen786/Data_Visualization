# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/LabWork_16th_April/FindLongestLine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open("file1.txt", "r")

longest = ""

for line in f:
    if len(line) > len(longest):
        longest = line

f.close()

print("Longest line:", longest)
print("Length:", len(longest))
