# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/SetProblem(LabAssignment_23rdMarch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set difference and intersection problem statement
#-----------------------------------------------------
# Input sets
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# Find common elements
intersection = set1 & set2

# Find elements in set1 but not in set2
difference = set1 - set2

# Output result
print("Intersection:", intersection)
print("Difference:", difference)
# Out:
# Intersection: {3, 4}
# Difference: {1, 2}
