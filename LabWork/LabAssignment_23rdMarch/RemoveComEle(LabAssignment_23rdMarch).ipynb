# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/RemoveComEle(LabAssignment_23rdMarch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Remove common elements
#------------------------------------------------
# Input lists
list1 = [1, 2, 3, 4]
list2 = [3, 4, 5]

result = []  # list to store filtered elements

# Loop through list1
for i in list1:
    # Add element if not present in list2
    if i not in list2:
        result.append(i)

# Output result
print("Result:", result)
# Out:
# Result: [1, 2]
