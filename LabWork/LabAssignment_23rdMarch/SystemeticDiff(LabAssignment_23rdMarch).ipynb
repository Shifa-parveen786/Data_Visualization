# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/SystemeticDiff(LabAssignment_23rdMarch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Systemetic difference of sets problem statement
#--------------------------------------------------
# Input sets
set1 = {1, 2, 3}
set2 = {3, 4, 5}

# Find elements present in only one set
result = set1 ^ set2

# Output result
print("Symmetric Difference:", result)
# Out:
# Symmetric Difference: {1, 2, 4, 5}
