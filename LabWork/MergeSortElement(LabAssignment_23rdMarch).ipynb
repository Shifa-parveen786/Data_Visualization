# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/LabWork/MergeSortElement(LabAssignment_23rdMarch).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Merge and sort unique elements problem statement
#-------------------------------------------------
# Input sets
set1 = {1, 2}
set2 = {1, 2, 3, 4}

# Check if set1 is subset of set2
result = set1.issubset(set2)

# Output result
print("Is subset:", result)
# Out:
# Is subset: True
