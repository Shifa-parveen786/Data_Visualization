# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/NumpyInPython/StoringString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# to create array
data = np.array([20,30,'python',70,90])
print(data)
# Out:
# ['20' '30' 'python' '70' '90']
