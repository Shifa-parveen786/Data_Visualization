# %% [markdown]
# <a href="https://colab.research.google.com/github/Shifa-parveen786/Data_Visualization/blob/main/ClassWork/NumpyInPython/ArrayDivision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
# to create array
data = np.array([20,30,70,90])
print(data)
#dividing each element by 5
numbers2 = data/5
print("After dividing each element by 5: ")
print(numbers2)
# Out:
# [20 30 70 90]
# After dividing each element by 5:
# [ 4.  6. 14. 18.]
